# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
print(tf.__version__)
# Out:
# 2.9.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import keras

# %%
import glob

# %%
import os

# %%
train_files=glob.glob("D:/SNT IS THE ROAD SAFE/Task 5/flowers/*/**")

# %%
len(train_files)
# Out:
# 15740

# %%
from PIL import Image
img=Image.open(train_files[0])
plt.imshow(img)

# %%
np.array(img).shape
# Out:
# (256, 256, 3)

# %%
from PIL import Image

# %%
from PIL import Image

for j in range(0,len(train_files)):
  x = train_files[j]  
  image = Image.open(x)
  imgGray = image.convert('L')
  imgGray.save(x)

# %%
train_files
# Out:
# ['D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\10091895024_a2ea04cda6_c.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1033455028_f0c6518ec9_c.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\10373087134_927b53fb9f_c.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1052212431_4963309d03_c.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1052219251_d03970e956_c.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1052586928_366c5255b8_c.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1052587144_34c9f0714c_c.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1053073526_188a5b816e_c.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1053075100_838051e5b7_c.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1053079170_650c3c6af6_c.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1053080414_1edf92651d_c.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1074784463_46a8df182c_c.jpg',
# ...

# %%
z='a'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/astilbe/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='b'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/bellflower/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='c'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/black_eyed_susan/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='d'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/calendula/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='e'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/california_poppy/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='f'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/carnation/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='g'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/common_daisy/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='h'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/coreopsis/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='i'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/daffodil/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='j'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/dandelion/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='k'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/iris/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='l'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/magnolia/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='m'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/rose/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='n'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/sunflower/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='o'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/tulip/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
z='p'
path="D:/SNT IS THE ROAD SAFE/Task 5/flowers/water_lily/"
for filename in os.listdir(path):
  str1=filename[0:-4]
  my_dest=str1+str(z)+'.jpg'
  my_source =path + filename
  my_dest =path + my_dest
  os.rename(my_source, my_dest)

# %%
train_files
# Out:
# ['D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\10091895024_a2ea04cda6_ca.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1033455028_f0c6518ec9_ca.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\10373087134_927b53fb9f_ca.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1052212431_4963309d03_ca.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1052219251_d03970e956_ca.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1052586928_366c5255b8_ca.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1052587144_34c9f0714c_ca.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1053073526_188a5b816e_ca.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1053075100_838051e5b7_ca.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1053079170_650c3c6af6_ca.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\astilbe\\1053080414_1edf92651d_ca.jpg',
# ...

# %%
img=Image.open(train_files[0])
train=np.array(img)
train.shape
# Out:
# (256, 256)

# %%
from random import shuffle
shuffle(train_files)
train_files
# Out:
# ['D:/SNT IS THE ROAD SAFE/Task 5/flowers\\california_poppy\\49336264011_b1b0b0a307_ce.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\tulip\\5700576160_7f521aee82_co.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\bellflower\\34591673261_8caa2a45c1_cb.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\bellflower\\14365793373_826993ce22_cb.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\calendula\\48097442831_c40e65db4d_cd.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\tulip\\8738207579_c115cc0b06_co.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\california_poppy\\51131876337_b02d44dfcf_ce.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\coreopsis\\4632631907_23d125d3c3_ch.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\iris\\5733087431_a47dbece27_ck.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\iris\\472111019_7db43e7cc7_ck.jpg',
#  'D:/SNT IS THE ROAD SAFE/Task 5/flowers\\daffodil\\8736747_5378b996ae_ci.jpg',
# ...

# %%
for j in range(0,len(train_files)):
  x = train_files[j]  
  image = Image.open(x)
  fi_img = image.resize((28,28))
  fi_img.save(x)

# %%
X_train=np.zeros((len(train_files),28,28))
Y_train=np.zeros((len(train_files)))

# %%
for i, fi in enumerate(train_files):
    im=Image.open(fi)
    X_train[i,:,:]=np.array(im)

    d=fi[-5]
    if (d=='a'):
        Y_train[i]=0
    elif (d=='b'):
        Y_train[i]=1
    elif (d=='c'):
        Y_train[i]=2
    elif (d=='d'):
        Y_train[i]=3
    elif (d=='e'):
        Y_train[i]=4
    elif (d=='f'):
        Y_train[i]=5
    elif (d=='g'):
        Y_train[i]=6
    elif (d=='h'):
        Y_train[i]=7
    elif (d=='i'):
        Y_train[i]=8
    elif (d=='j'):
        Y_train[i]=9
    elif (d=='k'):
        Y_train[i]=10
    elif (d=='l'):
        Y_train[i]=11
    elif (d=='m'):
        Y_train[i]=12
    elif (d=='n'):
        Y_train[i]=13
    elif (d=='o'):
        Y_train[i]=14
    elif (d=='p'):
        Y_train[i]=15

# %%
X_train=X_train/225.0

# %%
X_train.shape
# Out:
# (15740, 28, 28)

# %%
X_train[0]
# Out:
# array([[0.95111111, 0.89777778, 0.93777778, 0.90666667, 0.95555556,
#         0.92444444, 0.96888889, 0.96      , 0.97333333, 0.93333333,
#         0.92888889, 0.92444444, 0.89777778, 0.92      , 0.95111111,
#         0.92888889, 0.92444444, 0.99111111, 0.92      , 0.98222222,
#         0.90666667, 0.92888889, 0.94666667, 0.95555556, 0.92444444,
#         0.94666667, 0.88444444, 1.00444444],
#        [0.73777778, 0.44      , 0.53777778, 0.60888889, 0.60444444,
#         0.53777778, 0.55111111, 0.52888889, 0.49777778, 0.61777778,
#         0.70222222, 0.60888889, 0.53333333, 0.64      , 0.65333333,
#         0.47555556, 0.53333333, 0.50666667, 0.34666667, 0.30666667,
#         0.28      , 0.34222222, 0.42666667, 0.43111111, 0.35111111,
#         0.38666667, 0.45777778, 0.80444444],
#        [0.73777778, 0.19555556, 0.33777778, 0.48444444, 0.47555556,
#         0.43555556, 0.41777778, 0.41333333, 0.47111111, 0.55555556,
# ...

# %%
X_train[0].shape
Y_train
# Out:
# array([ 4., 14.,  1., ...,  8.,  3.,  9.])

# %%
X_train=X_train.reshape(len(train_files),28,28,1)

# %%
#two types selectors functions: 1. INT  2. Choice
def build_model(hp):  
  model = keras.Sequential([
    keras.layers.Conv2D(
        filters=hp.Int('conv_1_filter', min_value=32, max_value=128, step=16),#min value of filter you want
        kernel_size=hp.Choice('conv_1_kernel', values = [3,5]),#picks like mcq
        activation='relu',
        input_shape=(28,28,1)
    ),
      #for i in range(0,hp.Int(....)) this will also work
    keras.layers.Conv2D(
        filters=hp.Int('conv_2_filter', min_value=32, max_value=64, step=16),# ihave added this line extra in comparison to the old model
        kernel_size=hp.Choice('conv_2_kernel', values = [3,5]),
        activation='relu'
    ),
    keras.layers.Flatten(),
    keras.layers.Dense(
        units=hp.Int('dense_1_units', min_value=32, max_value=128, step=16),
        activation='relu'
    ),
    keras.layers.Dense(16, activation='softmax')
  ])
  
  model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-2, 1e-3])),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
  
  return model

# %%
from keras_tuner import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters

# %%
tuner_search=RandomSearch(build_model,
                          objective='val_accuracy',
                          max_trials=5,directory='output',project_name="randomsearch_efficientnet")
# Out:
# INFO:tensorflow:Reloading Oracle from existing project output\randomsearch_efficientnet\oracle.json

# %%
tuner_search.search(X_train,Y_train,epochs=3,validation_split=0.1)
# Out:
# Trial 5 Complete [00h 01m 42s]
# val_accuracy: 0.31067344546318054
#
# Best val_accuracy So Far: 0.31067344546318054
# Total elapsed time: 00h 08m 08s
# INFO:tensorflow:Oracle triggered exit

# %%
model=tuner_search.get_best_models(num_models=1)[0]

# %%
tuner_search

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 26, 26, 96)        960
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 48)        41520
#
#  flatten (Flatten)           (None, 27648)             0
#
#  dense (Dense)               (None, 80)                2211920
#
#  dense_1 (Dense)             (None, 16)                1296
#
# ...
# Total params: 2,255,696
# Trainable params: 2,255,696
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, Y_train, epochs=10, validation_split=0.1, initial_epoch=3)
# Out:
# Epoch 4/10
# 443/443 [==============================] - 34s 75ms/step - loss: 1.5195 - accuracy: 0.5220 - val_loss: 2.3620 - val_accuracy: 0.3297
# Epoch 5/10
# 443/443 [==============================] - 33s 75ms/step - loss: 1.0844 - accuracy: 0.6587 - val_loss: 2.6979 - val_accuracy: 0.2795
# Epoch 6/10
# 443/443 [==============================] - 33s 75ms/step - loss: 0.6853 - accuracy: 0.7923 - val_loss: 3.1619 - val_accuracy: 0.2973
# Epoch 7/10
# 443/443 [==============================] - 33s 75ms/step - loss: 0.3921 - accuracy: 0.8868 - val_loss: 4.0749 - val_accuracy: 0.2859
# Epoch 8/10
# 443/443 [==============================] - 33s 75ms/step - loss: 0.2014 - accuracy: 0.9467 - val_loss: 5.0211 - val_accuracy: 0.2929
# Epoch 9/10
# 443/443 [==============================] - 33s 75ms/step - loss: 0.1129 - accuracy: 0.9711 - val_loss: 5.5731 - val_accuracy: 0.2637
# Epoch 10/10
# ...

# %%
z=model.predict(X_train)
# Out:
# 492/492 [==============================] - 9s 19ms/step

# %%
z1=np.argmax(z,axis=1)

# %%
print(z1)
# Out:
# [ 4 14  1 ...  6 13 11]

# %%
Y_train
# Out:
# array([ 4., 14.,  1., ...,  8.,  3.,  9.])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(z1,Y_train)
# Out:
# 0.9
